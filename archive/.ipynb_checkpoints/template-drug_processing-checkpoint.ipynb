# %%
import pandas as pd
path = 'data/drug_type.csv'
df = pd.read_csv(path)
df.head()
# Out:
#         DRUG_NAME             PUTATIVE_TARGET PATHWAY_NAME
# 0  5-Fluorouracil  Antimetabolite (DNA & RNA)        Other
# 1  5-Fluorouracil  Antimetabolite (DNA & RNA)        Other
# 2  5-Fluorouracil  Antimetabolite (DNA & RNA)        Other
# 3  5-Fluorouracil  Antimetabolite (DNA & RNA)        Other
# 4  5-Fluorouracil  Antimetabolite (DNA & RNA)        Other

# %%
df.drop_duplicates()
# Out:
#              DRUG_NAME                    PUTATIVE_TARGET  \
# 0       5-Fluorouracil         Antimetabolite (DNA & RNA)
# 806             ABT737  BCL2, BCL-XL,  BCL-W, BCL-B, BFL1
# 1557          Acetalax                                NaN
# 2285          Afatinib                        ERBB2, EGFR
# 3090       Afuresertib                   AKT1, AKT2, AKT3
# ...                ...                                ...
# 132258          WZ4003                       NUAK1, NUAK2
# 132986          XAV939                       TNKS1, TNKS2
# 133714        YK-4-279                     RNA helicase A
# 134466        ZM447439                       AURKA, AURKB
# 134514     Zoledronate                                NaN
#
#                 PATHWAY_NAME
# 0                      Other
# 806     Apoptosis regulation
# 1557            Unclassified
# 2285          EGFR signaling
# 3090     PI3K/MTOR signaling
# ...                      ...
# 132258        Other, kinases
# ...

# %%
df.to_csv('drug_unique.csv')
