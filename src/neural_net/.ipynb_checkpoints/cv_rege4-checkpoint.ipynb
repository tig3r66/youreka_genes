# %%
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
# for data scaling and splitting
from sklearn.preprocessing import MinMaxScaler 
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
# for neural net
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras import regularizers
# for evaluation
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
# data plotting
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data/combined_expression.csv")
data['cluster'].replace([1, 2],[0, 1],inplace=True)
data.head()
# Out:
#    CELL_LINE_NAME  cluster    TSPAN6      TNMD       DPM1     SCYL3  C1orf112  \
# 0         1240123        1  8.319417  3.111183   9.643558  4.757258  3.919757
# 1         1240131        0  7.611268  2.704739  10.276079  3.650299  3.481567
# 2         1240132        0  7.678658  2.845781  10.180954  3.573048  3.431235
# 3         1240134        0  3.265063  3.063746  10.490285  3.340791  3.676912
# 4         1240140        0  7.090138  2.988043  10.264692  4.119555  3.432585
#
#         FGR       CFH     FUCA2  ...   C6orf10   TMEM225    NOTCH4      PBX2  \
# 0  3.602185  3.329644  9.076950  ...  3.085394  3.462811  3.339030  4.614897
# 1  3.145538  3.565127  7.861068  ...  2.801456  2.985889  3.180068  5.415729
# 2  3.090781  4.116643  8.121190  ...  2.934962  2.952937  3.164655  5.707506
# 3  3.512821  3.873922  8.790851  ...  3.041839  3.398847  3.106710  5.773963
# 4  3.308033  3.318371  6.927761  ...  3.028787  3.225982  3.275820  5.334283
#
#        AGER      RNF5    AGPAT1    DFNB59     PRRT1     FKBPL
# 0  3.395845  3.419193  3.971646  3.729310  3.320022  6.447316
# 1  3.299858  3.028414  3.877889  3.911516  3.379405  4.729557
# 2  3.434295  2.961345  4.272194  3.085696  3.002557  5.653588
# 3  3.412641  3.136110  4.422262  3.522122  3.509437  5.953242
# 4  3.864678  3.259242  3.840581  5.809553  3.674587  5.577503
#
# [5 rows x 16384 columns]

# %%
data.shape
# Out:
# (541, 16384)

# %%
selected_genes = pd.read_csv('cleaned/boruta.csv')
selected_genes = selected_genes.values.tolist()
selected_genes = list(itertools.chain(*selected_genes))

# %%
# retrieving proper columns
X = data.loc[:, selected_genes]
y = data['cluster'].values
# scaling the data
scalar = MinMaxScaler()
x_scaled = scalar.fit_transform(X)
# splitting data (20% test, 80% train)
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2)
sm = SMOTE()
X_train, y_train = sm.fit_sample(X_train, y_train)

# %% [markdown]
# # K-Folds Evaluation Function

# %%
def cv_eval(model, n_folds, X, y):
    """K-fold validation function for evaluation of a Keras model.
    Arguments:
        model: the model to evaluate.
        n_folds (int): the number of cross-folds.
        X: values of the feature variables.
        y: values of the classification.
    Returns:
        cms (list): confusion matrix for each cross-fold.
        histories (list): model metrics for each cross-fold.
        tprs (list): the True Positive Rate for each cross-fold.
        base_fpr (list): the cutoff points for the ROC curve.
    """
    kf = KFold(n_splits=n_folds)
    cms = []  # confusion matrix results
    histories = []  # for model analysis
    tprs = []  # for ROC analysis
    base_fpr = np.linspace(0, 1, 101)  # for ROC analysis

    for i_train, i_test in kf.split(X, y):
        X_train, X_test = X.iloc[i_train].values, X.iloc[i_test].values
        y_train, y_test = y[i_train], y[i_test]
        # recording model metrics and confusion matrix
        histories.append(model.fit(X_train, y_train, validation_data=(X_test, y_test)))
        cms.append(confusion_matrix(y_test, model.predict(X_test)))
        # recording for auc
        y_score = model.predict_proba(X_test)
        fpr, tpr, _ = roc_curve(y_test, y_score[:, 1])
        tpr = np.interp(base_fpr, fpr, tpr)
        tpr[0] = 0.
        tprs.append(tpr)

    return cms, histories, tprs, base_fpr

# %% [markdown]
# # Confusion Matrix Plotting Function

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True, cbar=True):
    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    fig = plt.figure(figsize=(4, 3), dpi=200)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names)
        plt.yticks(tick_marks, target_names, rotation=90, verticalalignment='center')
#         plt.yticks([], ['', ''])

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    if cbar:
        plt.colorbar()

    plt.tight_layout()
    plt.ylabel('True')
    plt.xlabel('Predicted\naccuracy={:0.3f}; misclass={:0.3f}'.format(accuracy, misclass))
    plt.show()

    return fig

# %% [markdown]
# # 1 Hidden Layer

# %%
def hidden1(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    # hidden layer
    model.add(Dense(neurons, activation='relu',
                    kernel_regularizer=regularizers.l2(1e-4)
                   ))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    # output layer
    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model1 = KerasClassifier(build_fn=hidden1, epochs=25, batch_size=16)
cm_results1, history1, tpr1, base_fpr1 = cv_eval(model1, 5, X, y)
# Out:
# Train on 432 samples, validate on 109 samples
# Epoch 1/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6151 - accuracy: 0.7153 - val_loss: 0.4115 - val_accuracy: 0.8532
# Epoch 2/25
# 432/432 [==============================] - 0s 338us/sample - loss: 0.4545 - accuracy: 0.8241 - val_loss: 0.4607 - val_accuracy: 0.8349
# Epoch 3/25
# 432/432 [==============================] - 0s 327us/sample - loss: 0.4206 - accuracy: 0.8287 - val_loss: 0.2577 - val_accuracy: 0.9266
# Epoch 4/25
# 432/432 [==============================] - 0s 318us/sample - loss: 0.4363 - accuracy: 0.8380 - val_loss: 0.2480 - val_accuracy: 0.9358
# Epoch 5/25
# 432/432 [==============================] - 0s 328us/sample - loss: 0.4182 - accuracy: 0.8194 - val_loss: 0.2246 - val_accuracy: 0.9358
# Epoch 6/25
# 432/432 [==============================] - 0s 319us/sample - loss: 0.3846 - accuracy: 0.8542 - val_loss: 0.2126 - val_accuracy: 0.9450
# Epoch 7/25
# 432/432 [==============================] - 0s 329us/sample - loss: 0.3934 - accuracy: 0.8426 - val_loss: 0.2198 - val_accuracy: 0.9358
# Epoch 8/25
# 432/432 [==============================] - 0s 328us/sample - loss: 0.3907 - accuracy: 0.8588 - val_loss: 0.2304 - val_accuracy: 0.9358
# Epoch 9/25
# 432/432 [==============================] - 0s 321us/sample - loss: 0.3473 - accuracy: 0.8588 - val_loss: 0.2754 - val_accuracy: 0.9174
# Epoch 10/25
# 432/432 [==============================] - 0s 330us/sample - loss: 0.3734 - accuracy: 0.8449 - val_loss: 0.2331 - val_accuracy: 0.9266
# Epoch 11/25
# 432/432 [==============================] - 0s 326us/sample - loss: 0.3627 - accuracy: 0.8611 - val_loss: 0.3184 - val_accuracy: 0.8991
# Epoch 12/25
# 432/432 [==============================] - 0s 342us/sample - loss: 0.3743 - accuracy: 0.8542 - val_loss: 0.4273 - val_accuracy: 0.7706
# Epoch 13/25
# 433/433 [==============================] - 0s 529us/sample - loss: 0.3548 - accuracy: 0.8614 - val_loss: 0.4317 - val_accuracy: 0.8333
# Epoch 13/25
# 433/433 [==============================] - 0s 541us/sample - loss: 0.3971 - accuracy: 0.8684 - val_loss: 0.4878 - val_accuracy: 0.8056
# Epoch 14/25
# 433/433 [==============================] - 0s 532us/sample - loss: 0.3361 - accuracy: 0.8822 - val_loss: 0.4053 - val_accuracy: 0.8426
# Epoch 15/25
# 433/433 [==============================] - 0s 575us/sample - loss: 0.3219 - accuracy: 0.8891 - val_loss: 0.3952 - val_accuracy: 0.8333
# Epoch 16/25
# 433/433 [==============================] - 0s 557us/sample - loss: 0.3270 - accuracy: 0.8730 - val_loss: 0.4041 - val_accuracy: 0.8426
# Epoch 17/25
# 433/433 [==============================] - 0s 535us/sample - loss: 0.3134 - accuracy: 0.8891 - val_loss: 0.4144 - val_accuracy: 0.8519
# Epoch 18/25
# 433/433 [==============================] - 0s 562us/sample - loss: 0.3188 - accuracy: 0.8915 - val_loss: 0.4668 - val_accuracy: 0.8056
# Epoch 19/25
# 433/433 [==============================] - 0s 571us/sample - loss: 0.3022 - accuracy: 0.8938 - val_loss: 0.4063 - val_accuracy: 0.8519
# Epoch 20/25
# 433/433 [==============================] - 0s 601us/sample - loss: 0.3196 - accuracy: 0.8845 - val_loss: 0.4090 - val_accuracy: 0.8519
# Epoch 21/25
# 433/433 [==============================] - 0s 586us/sample - loss: 0.3106 - accuracy: 0.8799 - val_loss: 0.5533 - val_accuracy: 0.7315
# Epoch 22/25
# 433/433 [==============================] - 0s 618us/sample - loss: 0.3215 - accuracy: 0.8822 - val_loss: 0.4219 - val_accuracy: 0.8333
# Epoch 23/25
# 433/433 [==============================] - 0s 625us/sample - loss: 0.3177 - accuracy: 0.8799 - val_loss: 0.5129 - val_accuracy: 0.7685
# Epoch 24/25
# 433/433 [==============================] - 0s 577us/sample - loss: 0.3270 - accuracy: 0.8776 - val_loss: 0.5502 - val_accuracy: 0.7500
# Epoch 25/25
# 433/433 [==============================] - 0s 598us/sample - loss: 0.2934 - accuracy: 0.8868 - val_loss: 0.4100 - val_accuracy: 0.8611

# %%
cm1 = [[0, 0]]
k, l = 0, 0
for i in cm_results1:
    for j in cm_results1[0]:
        cm1[k][l] += j
        l = (l+1) % 2
    j = (j+1) % 2
cm1 = np.array(cm1[0])

# %%
plt.rcParams.update({'font.size': 10})
cm_hidden1 = plot_confusion_matrix(cm1, ['responder', 'non-responder'], title='1 Hidden Layer', normalize=False, cbar=False)

# %% [markdown]
# # 5-Fold Validation for 5 Hidden Layers

# %%
def hidden5(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 5 hidden layers
    for i in range(5):
        model.add(Dense(neurons, activation='relu',
                        kernel_regularizer=regularizers.l2(1e-4)
                       ))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model5 = KerasClassifier(build_fn=hidden5, epochs=25, batch_size=16)
cm_results5, history5, tprs5, base_fpr5 = cv_eval(model5, 5, X, y)
# Out:
# Train on 432 samples, validate on 109 samples
# Epoch 1/25
# 432/432 [==============================] - 7s 15ms/sample - loss: 0.7719 - accuracy: 0.6204 - val_loss: 0.8880 - val_accuracy: 0.6697
# Epoch 2/25
# 432/432 [==============================] - 0s 1ms/sample - loss: 0
25
# 433/433 [==============================] - 1s 1ms/sample - loss: 0.4194 - accuracy: 0.8637 - val_loss: 0.4368 - val_accuracy: 0.8611
# Epoch 23/25
# 433/433 [==============================] - 1s 1ms/sample - loss: 0.4383 - accuracy: 0.8268 - val_loss: 0.4690 - val_accuracy: 0.8056
# Epoch 24/25
# 433/433 [==============================] - 1s 1ms/sample - loss: 0.4262 - accuracy: 0.8545 - val_loss: 0.4497 - val_accuracy: 0.8241
# Epoch 25/25
# 433/433 [==============================] - 1s 1ms/sample - loss: 0.4478 - accuracy: 0.8476 - val_loss: 0.4727 - val_accuracy: 0.8056

# %%
cm5 = [[0, 0]]
k, l = 0, 0
for i in cm_results5:
    for j in cm_results5[0]:
        cm5[k][l] += j
        l = (l+1) % 2
    j = (j+1) % 2
cm5 = np.array(cm5[0])

# %%
cm_hidden5 = plot_confusion_matrix(cm5, ['responder', 'non-responder'], title='5 Hidden Layers', normalize=False, cbar=False)

# %% [markdown]
# # 10 Hidden Layers

# %%
def hidden10(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 10 hidden layers
    for i in range(10):
        model.add(Dense(neurons, activation='relu',
                        kernel_regularizer=regularizers.l2(1e-4)
                       ))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model10 = KerasClassifier(build_fn=hidden10, epochs=25, batch_size=16)
cm_results10, history10, tprs10, base_fpr10 = cv_eval(model10, 5, X, y)
# Out:
# Train on 432 samples, validate on 109 samples
# Epoch 1/25
# 432/432 [==============================] - 10s 24ms/sample - loss: 0.9610 - accuracy: 0.5324 - val_loss: 0.8291 - val_accuracy: 0.2844
# Epoch 2/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.9404 - accuracy: 0.5602 - val_loss: 0.7355 - val_accuracy: 0.7064
# Epoch 3/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.8927 - accuracy: 0.5556 - val_loss: 0.7877 - val_accuracy: 0.6606
# Epoch 4/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.9087 - accuracy: 0.5718 - val_loss: 0.7938 - val_accuracy: 0.6697
# Epoch 5/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.8379 - accuracy: 0.5648 - val_loss: 0.8064 - val_accuracy: 0.6330
# Epoch 6/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.8097 - accuracy: 0.5926 - val_loss: 0.6903 - val_accuracy: 0.6697
# Epoch 7/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.7853 - accuracy: 0.6296 - val_loss: 0.6647 - val_accuracy: 0.7156
# Epoch 8/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.7347 - accuracy: 0.6829 - val_loss: 0.5724 - val_accuracy: 0.8073
# Epoch 9/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6987 - accuracy: 0.7176 - val_loss: 0.5849 - val_accuracy: 0.8349
# Epoch 10/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6821 - accuracy: 0.7106 - val_loss: 0.5569 - val_accuracy: 0.8349
# Epoch 11/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6999 - accuracy: 0.7361 - val_loss: 0.5096 - val_accuracy: 0.8991
# Epoch 12/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6751 - accuracy: 0.7361 - val_loss: 0.4570 - val_accuracy: 0.9266
# Epoch 13/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6597 - accuracy: 0.7431 - val_loss: 0.4106 - val_accuracy: 0.9358
# Epoch 14/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6556 - accuracy: 0.7338 - val_loss: 0.4036 - val_accuracy: 0.9174
# Epoch 15/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6422 - accuracy: 0.7546 - val_loss: 0.3890 - val_accuracy: 0.9266
# Epoch 16/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6391 - accuracy: 0.7616 - val_loss: 0.3908 - val_accuracy: 0.9450
# Epoch 17/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6134 - accuracy: 0.7639 - val_loss: 0.3754 - val_accuracy: 0.9266
# Epoch 18/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6332 - accuracy: 0.7731 - val_loss: 0.3895 - val_accuracy: 0.9358
# Epoch 19/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6430 - accuracy: 0.7778 - val_loss: 0.3808 - val_accuracy: 0.9266
# Epoch 20/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6262 - accuracy: 0.7778 - val_loss: 0.3781 - val_accuracy: 0.9450
# Epoch 21/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6340 - accuracy: 0.7917 - val_loss: 0.3947 - val_accuracy: 0.9358
# Epoch 22/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6257 - accuracy: 0.7847 - val_loss: 0.3885 - val_accuracy: 0.9266
# Epoch 23/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6376 - accuracy: 0.7685 - val_loss: 0.3869 - val_accuracy: 0.9358
# Epoch 24/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.6120 - accuracy: 0.7801 - val_loss: 0.3839 - val_accuracy: 0.9358
# Epoch 25/25
# 432/432 [==============================] - 1s 2ms/sample - loss: 0.5918 - accuracy: 0.7940 - val_loss: 0.3825 - val_accuracy: 0.9358
# Train on 433 samples, validate on 108 samples
# Epoch 1/25
# 433/433 [==============================] - 13s 29ms/sample - loss: 1.0138 - accuracy: 0.5173 - val_loss: 0.7373 - val_accuracy: 0.7778
# Epoch 2/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.9605 - accuracy: 0.5335 - val_loss: 0.9146 - val_accuracy: 0.2407
# Epoch 3/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8825 - accuracy: 0.5843 - val_loss: 1.1211 - val_accuracy: 0.2037
# Epoch 4/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8979 - accuracy: 0.5843 - val_loss: 0.7343 - val_accuracy: 0.7870
# Epoch 5/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8181 - accuracy: 0.6120 - val_loss: 0.7003 - val_accuracy: 0.6759
# Epoch 6/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7885 - accuracy: 0.6513 - val_loss: 0.6955 - val_accuracy: 0.6759
# Epoch 7/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7136 - accuracy: 0.7067 - val_loss: 0.6928 - val_accuracy: 0.6852
# Epoch 8/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7296 - accuracy: 0.6836 - val_loss: 0.6202 - val_accuracy: 0.7315
# Epoch 9/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6832 - accuracy: 0.7182 - val_loss: 0.6125 - val_accuracy: 0.7685
# Epoch 10/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6910 - accuracy: 0.7598 - val_loss: 0.6039 - val_accuracy: 0.7593
# Epoch 11/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6173 - accuracy: 0.7552 - val_loss: 0.5823 - val_accuracy: 0.7870
# Epoch 12/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5905 - accuracy: 0.8060 - val_loss: 0.5605 - val_accuracy: 0.8148
# Epoch 13/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6059 - accuracy: 0.8106 - val_loss: 0.5642 - val_accuracy: 0.8148
# Epoch 14/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6231 - accuracy: 0.7691 - val_loss: 0.5500 - val_accuracy: 0.8241
# Epoch 15/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5499 - accuracy: 0.8291 - val_loss: 0.5585 - val_accuracy: 0.8241
# Epoch 16/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5827 - accuracy: 0.8037 - val_loss: 0.5465 - val_accuracy: 0.8333
# Epoch 17/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6023 - accuracy: 0.7921 - val_loss: 0.5483 - val_accuracy: 0.8333
# Epoch 18/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6391 - accuracy: 0.7921 - val_loss: 0.5275 - val_accuracy: 0.8241
# Epoch 19/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6153 - accuracy: 0.7783 - val_loss: 0.5150 - val_accuracy: 0.8241
# Epoch 20/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5916 - accuracy: 0.7991 - val_loss: 0.5165 - val_accuracy: 0.8241
# Epoch 21/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6221 - accuracy: 0.7968 - val_loss: 0.5292 - val_accuracy: 0.8241
# Epoch 22/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5915 - accuracy: 0.8037 - val_loss: 0.5251 - val_accuracy: 0.8241
# Epoch 23/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5853 - accuracy: 0.8106 - val_loss: 0.5237 - val_accuracy: 0.8333
# Epoch 24/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5818 - accuracy: 0.8083 - val_loss: 0.5229 - val_accuracy: 0.8333
# Epoch 25/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5387 - accuracy: 0.8106 - val_loss: 0.5271 - val_accuracy: 0.8241
# Train on 433 samples, validate on 108 samples
# Epoch 1/25
# 433/433 [==============================] - 15s 34ms/sample - loss: 1.0025 - accuracy: 0.4988 - val_loss: 0.7604 - val_accuracy: 0.7222
# Epoch 2/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.9249 - accuracy: 0.5497 - val_loss: 0.6132 - val_accuracy: 0.7500
# Epoch 3/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8959 - accuracy: 0.5958 - val_loss: 0.6609 - val_accuracy: 0.7130
# Epoch 4/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8480 - accuracy: 0.5935 - val_loss: 0.6502 - val_accuracy: 0.7130
# Epoch 5/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7474 - accuracy: 0.6813 - val_loss: 0.6367 - val_accuracy: 0.7130
# Epoch 6/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7495 - accuracy: 0.6859 - val_loss: 0.6927 - val_accuracy: 0.7130
# Epoch 7/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7030 - accuracy: 0.7067 - val_loss: 0.7389 - val_accuracy: 0.7130
# Epoch 8/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6811 - accuracy: 0.7113 - val_loss: 0.6526 - val_accuracy: 0.7222
# Epoch 9/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6416 - accuracy: 0.7483 - val_loss: 0.6524 - val_accuracy: 0.7407
# Epoch 10/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5788 - accuracy: 0.7783 - val_loss: 0.6522 - val_accuracy: 0.7870
# Epoch 11/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6496 - accuracy: 0.7621 - val_loss: 0.6337 - val_accuracy: 0.8056
# Epoch 12/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6227 - accuracy: 0.7760 - val_loss: 0.6641 - val_accuracy: 0.8333
# Epoch 13/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6110 - accuracy: 0.7806 - val_loss: 0.6223 - val_accuracy: 0.8241
# Epoch 14/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6038 - accuracy: 0.7621 - val_loss: 0.6333 - val_accuracy: 0.8148
# Epoch 15/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5852 - accuracy: 0.7991 - val_loss: 0.6366 - val_accuracy: 0.8148
# Epoch 16/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5416 - accuracy: 0.8430 - val_loss: 0.6656 - val_accuracy: 0.8241
# Epoch 17/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5428 - accuracy: 0.8199 - val_loss: 0.6672 - val_accuracy: 0.8241
# Epoch 18/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5647 - accuracy: 0.8083 - val_loss: 0.6603 - val_accuracy: 0.8241
# Epoch 19/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5806 - accuracy: 0.8037 - val_loss: 0.6761 - val_accuracy: 0.8333
# Epoch 20/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5744 - accuracy: 0.8083 - val_loss: 0.6562 - val_accuracy: 0.8333
# Epoch 21/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5684 - accuracy: 0.8060 - val_loss: 0.6066 - val_accuracy: 0.8333
# Epoch 22/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5640 - accuracy: 0.8083 - val_loss: 0.6064 - val_accuracy: 0.8241
# Epoch 23/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5616 - accuracy: 0.8268 - val_loss: 0.6012 - val_accuracy: 0.8241
# Epoch 24/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5841 - accuracy: 0.8129 - val_loss: 0.5937 - val_accuracy: 0.8241
# Epoch 25/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5464 - accuracy: 0.8222 - val_loss: 0.5975 - val_accuracy: 0.8241
# Train on 433 samples, validate on 108 samples
# Epoch 1/25
# 433/433 [==============================] - 14s 32ms/sample - loss: 0.9961 - accuracy: 0.5012 - val_loss: 0.7413 - val_accuracy: 0.5556
# Epoch 2/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.9539 - accuracy: 0.5196 - val_loss: 0.7855 - val_accuracy: 0.5926
# Epoch 3/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.9057 - accuracy: 0.5751 - val_loss: 0.8855 - val_accuracy: 0.4352
# Epoch 4/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8382 - accuracy: 0.5912 - val_loss: 0.8569 - val_accuracy: 0.4444
# Epoch 5/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8422 - accuracy: 0.5912 - val_loss: 0.7787 - val_accuracy: 0.5185
# Epoch 6/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7973 - accuracy: 0.6351 - val_loss: 0.7849 - val_accuracy: 0.4537
# Epoch 7/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7628 - accuracy: 0.6420 - val_loss: 0.7895 - val_accuracy: 0.5556
# Epoch 8/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6692 - accuracy: 0.7044 - val_loss: 0.6615 - val_accuracy: 0.6852
# Epoch 9/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7235 - accuracy: 0.6882 - val_loss: 0.5955 - val_accuracy: 0.8426
# Epoch 10/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7140 - accuracy: 0.6859 - val_loss: 0.6172 - val_accuracy: 0.7778
# Epoch 11/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6968 - accuracy: 0.7021 - val_loss: 0.6351 - val_accuracy: 0.7407
# Epoch 12/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6857 - accuracy: 0.7413 - val_loss: 0.5437 - val_accuracy: 0.8241
# Epoch 13/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6526 - accuracy: 0.7760 - val_loss: 0.5195 - val_accuracy: 0.8333
# Epoch 14/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6797 - accuracy: 0.7206 - val_loss: 0.5085 - val_accuracy: 0.8426
# Epoch 15/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6463 - accuracy: 0.7413 - val_loss: 0.5061 - val_accuracy: 0.8519
# Epoch 16/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6431 - accuracy: 0.7621 - val_loss: 0.4872 - val_accuracy: 0.8519
# Epoch 17/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6627 - accuracy: 0.7483 - val_loss: 0.4912 - val_accuracy: 0.8611
# Epoch 18/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6346 - accuracy: 0.7644 - val_loss: 0.4776 - val_accuracy: 0.8611
# Epoch 19/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5907 - accuracy: 0.8014 - val_loss: 0.4884 - val_accuracy: 0.8426
# Epoch 20/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6207 - accuracy: 0.7852 - val_loss: 0.4897 - val_accuracy: 0.8426
# Epoch 21/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6100 - accuracy: 0.7852 - val_loss: 0.4954 - val_accuracy: 0.8611
# Epoch 22/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6225 - accuracy: 0.7714 - val_loss: 0.5162 - val_accuracy: 0.8611
# Epoch 23/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6168 - accuracy: 0.7945 - val_loss: 0.5383 - val_accuracy: 0.8611
# Epoch 24/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6239 - accuracy: 0.7783 - val_loss: 0.5674 - val_accuracy: 0.8333
# Epoch 25/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5480 - accuracy: 0.8291 - val_loss: 0.5365 - val_accuracy: 0.8426
# Train on 433 samples, validate on 108 samples
# Epoch 1/25
# 433/433 [==============================] - 14s 32ms/sample - loss: 1.0135 - accuracy: 0.5450 - val_loss: 0.7471 - val_accuracy: 0.6389
# Epoch 2/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.9452 - accuracy: 0.5473 - val_loss: 0.8263 - val_accuracy: 0.3981
# Epoch 3/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.9544 - accuracy: 0.5658 - val_loss: 0.7779 - val_accuracy: 0.6296
# Epoch 4/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.9066 - accuracy: 0.5774 - val_loss: 0.7343 - val_accuracy: 0.6389
# Epoch 5/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.8424 - accuracy: 0.5820 - val_loss: 0.7710 - val_accuracy: 0.6389
# Epoch 6/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7617 - accuracy: 0.6259 - val_loss: 0.7338 - val_accuracy: 0.6389
# Epoch 7/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7859 - accuracy: 0.6397 - val_loss: 0.6384 - val_accuracy: 0.6852
# Epoch 8/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7343 - accuracy: 0.6674 - val_loss: 0.6591 - val_accuracy: 0.6667
# Epoch 9/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.7006 - accuracy: 0.6975 - val_loss: 0.5906 - val_accuracy: 0.7593
# Epoch 10/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6655 - accuracy: 0.7182 - val_loss: 0.5397 - val_accuracy: 0.8241
# Epoch 11/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5944 - accuracy: 0.7460 - val_loss: 0.5252 - val_accuracy: 0.8148
# Epoch 12/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6518 - accuracy: 0.7460 - val_loss: 0.5100 - val_accuracy: 0.8333
# Epoch 13/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5938 - accuracy: 0.7921 - val_loss: 0.5263 - val_accuracy: 0.8426
# Epoch 14/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6362 - accuracy: 0.7644 - val_loss: 0.5099 - val_accuracy: 0.8426
# Epoch 15/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6143 - accuracy: 0.7691 - val_loss: 0.5116 - val_accuracy: 0.8519
# Epoch 16/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6007 - accuracy: 0.7991 - val_loss: 0.5094 - val_accuracy: 0.8426
# Epoch 17/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5725 - accuracy: 0.7829 - val_loss: 0.5244 - val_accuracy: 0.8426
# Epoch 18/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6369 - accuracy: 0.7760 - val_loss: 0.5183 - val_accuracy: 0.8519
# Epoch 19/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5751 - accuracy: 0.8245 - val_loss: 0.5262 - val_accuracy: 0.8519
# Epoch 20/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6030 - accuracy: 0.7921 - val_loss: 0.5328 - val_accuracy: 0.8426
# Epoch 21/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5883 - accuracy: 0.8129 - val_loss: 0.5193 - val_accuracy: 0.8426
# Epoch 22/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5680 - accuracy: 0.7968 - val_loss: 0.5291 - val_accuracy: 0.8426
# Epoch 23/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.6060 - accuracy: 0.8060 - val_loss: 0.5219 - val_accuracy: 0.8519
# Epoch 24/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5809 - accuracy: 0.7945 - val_loss: 0.5163 - val_accuracy: 0.8426
# Epoch 25/25
# 433/433 [==============================] - 1s 2ms/sample - loss: 0.5742 - accuracy: 0.8129 - val_loss: 0.5172 - val_accuracy: 0.8426

# %%
cm10 = [[0, 0]]
k, l = 0, 0
for i in cm_results10:
    for j in cm_results10[0]:
        cm10[k][l] += j
        l = (l+1) % 2
    j = (j+1) % 2
cm10 = np.array(cm10[0])
cm10
# Out:
# array([[365,   0],
#        [ 35, 145]])

# %%
cm_hidden10 = plot_confusion_matrix(cm10, ['responder', 'non-responder'], title='10 Hidden Layers', normalize=False)

# %% [markdown]
# # Comparison Plots

# %%
# for 1 hidden layer
tprs1 = np.array(tpr1)
mean_tprs1 = tprs1.mean(axis=0)
std1 = tprs1.std(axis=0)
tprs_upper1 = mean_tprs1 + std1 / np.sqrt(5)
tprs_lower1 = mean_tprs1 - std1 / np.sqrt(5)
auc1 = auc(base_fpr1, mean_tprs1)

# %%
# for 5 hidden layers
tprs5 = np.array(tprs5)
mean_tprs5 = tprs5.mean(axis=0)
std5 = tprs5.std(axis=0)
tprs_upper5 = mean_tprs5 + std5 / np.sqrt(5)
tprs_lower5 = mean_tprs5 - std5 / np.sqrt(5)
auc5 = auc(base_fpr5, mean_tprs5)

# %%
# for 10 hidden layers
tprs10 = np.array(tprs10)
mean_tprs10 = tprs10.mean(axis=0)
std10 = tprs10.std(axis=0)
tprs_upper10 = mean_tprs10 + std10 / np.sqrt(5)
tprs_lower10 = mean_tprs1 - std10 / np.sqrt(5)
auc10 = auc(base_fpr10, mean_tprs10)

# %%
plt.style.use('seaborn-white')

plt.rcParams.update({'font.size': 14})
# combined figure
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 7), dpi=300)

# 1 hidden layer
ax1.plot(base_fpr1, mean_tprs1, 'k', linewidth=1)
ax1.fill_between(base_fpr1, tprs_lower1, tprs_upper1, alpha=0.2)
ax1.plot([0, 1], [0, 1], 'k--', linewidth=1)
ax1.set_xlim([0, 1])
ax1.set_ylim([0, 1.02])
ax1.set_title('1 Hidden Layer', fontsize=14)
ax1.set_ylabel('TPR', fontsize=14)
ax1.set_xlabel('FPR', fontsize=14)
ax1.legend(['mean AUC = ' + str(round(auc1, 3)) + '$\pm$' + str(round(np.mean(std1), 3)),
            'chance', '$\pm 1$ sem'],
           fontsize=12, loc='lower right')
ax1.text(-.1, 1.1, 'B', transform=ax1.transAxes, fontsize=16, fontweight='bold', va='top', ha='right')

# 5 hidden layers
ax2.plot(base_fpr5, mean_tprs5, color='k', linewidth=1)
ax2.fill_between(base_fpr5, tprs_lower5, tprs_upper5, alpha=0.2, color='r')
ax2.plot([0, 1], [0, 1], 'k--', linewidth=1)
ax2.set_xlim([0, 1])
ax2.set_ylim([0, 1.02])
ax2.set_title('5 Hidden Layers', fontsize=14)
ax2.set_ylabel('TPR', fontsize=14)
ax2.set_xlabel('FPR', fontsize=14)
ax2.legend(['mean AUC = ' + str(round(auc5, 3)) + '$\pm$' + str(round(np.mean(std5), 3)),
            'chance', '$\pm 1$ sem'],
           fontsize=12, loc='lower right')

# 10 hidden layers
ax3.plot(base_fpr10, mean_tprs10, color='k', linewidth=1)
ax3.fill_between(base_fpr10, tprs_lower10, tprs_upper10, alpha=0.2, color='g')
ax3.plot([0, 1], [0, 1], 'k--', linewidth=1)
ax3.set_xlim([0, 1])
ax3.set_ylim([0, 1.02])
ax3.set_title('10 Hidden Layers', fontsize=14)
ax3.set_ylabel('TPR', fontsize=14)
ax3.set_xlabel('FPR', fontsize=14)
ax3.legend(['mean AUC = ' + str(round(auc10, 3)) + '$\pm$' + str(round(np.mean(std10), 3)),
            'chance', '$\pm 1$ sem'],
           fontsize=12, loc='lower right')

# merged
## 1
ax4.plot(base_fpr1, mean_tprs1, '#ff0000', linewidth=1.5, alpha=0.75)
ax4.fill_between(base_fpr1, tprs_lower1, tprs_upper1, alpha=0.2)
## 5
ax4.plot(base_fpr5, mean_tprs5, '#1a236e', linewidth=1.5, alpha=1)
ax4.fill_between(base_fpr5, tprs_lower5, tprs_upper5, alpha=0.2, color='r')
## 10
ax4.plot(base_fpr10, mean_tprs10, '#32CD32', linewidth=1.5, alpha=1)
ax4.fill_between(base_fpr10, tprs_lower10, tprs_upper10, alpha=0.2, color='g')
ax4.plot([0, 1], [0, 1], 'k--', linewidth=1)
ax4.set_xlim([0, 1])
ax4.set_ylim([0, 1.02])
ax4.set_title('Merged', fontsize=14)
ax4.set_ylabel('TPR', fontsize=14)
ax4.set_xlabel('FPR', fontsize=14)
ax4.legend(['1 hidden layers', '5 hidden layers', '10 hidden layers'], fontsize=12, loc='lower right')

for ax in fig.get_axes():
    ax.label_outer()
fig.tight_layout()

# %%
fig.savefig('figures/roc_combined.png')
