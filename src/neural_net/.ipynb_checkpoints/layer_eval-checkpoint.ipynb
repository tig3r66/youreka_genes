# %%
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# for data scaling and splitting
from sklearn.preprocessing import MinMaxScaler 
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
# for neural net
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras import regularizers
# for evaluation
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv("data/combined_expression.csv")
data.head()
# Out:
#    CELL_LINE_NAME  cluster    TSPAN6      TNMD       DPM1     SCYL3  C1orf112  \
# 0         1240123        2  8.319417  3.111183   9.643558  4.757258  3.919757
# 1         1240131        1  7.611268  2.704739  10.276079  3.650299  3.481567
# 2         1240132        1  7.678658  2.845781  10.180954  3.573048  3.431235
# 3         1240134        1  3.265063  3.063746  10.490285  3.340791  3.676912
# 4         1240140        1  7.090138  2.988043  10.264692  4.119555  3.432585
#
#         FGR       CFH     FUCA2  ...   C6orf10   TMEM225    NOTCH4      PBX2  \
# 0  3.602185  3.329644  9.076950  ...  3.085394  3.462811  3.339030  4.614897
# 1  3.145538  3.565127  7.861068  ...  2.801456  2.985889  3.180068  5.415729
# 2  3.090781  4.116643  8.121190  ...  2.934962  2.952937  3.164655  5.707506
# 3  3.512821  3.873922  8.790851  ...  3.041839  3.398847  3.106710  5.773963
# 4  3.308033  3.318371  6.927761  ...  3.028787  3.225982  3.275820  5.334283
#
#        AGER      RNF5    AGPAT1    DFNB59     PRRT1     FKBPL
# 0  3.395845  3.419193  3.971646  3.729310  3.320022  6.447316
# 1  3.299858  3.028414  3.877889  3.911516  3.379405  4.729557
# 2  3.434295  2.961345  4.272194  3.085696  3.002557  5.653588
# 3  3.412641  3.136110  4.422262  3.522122  3.509437  5.953242
# 4  3.864678  3.259242  3.840581  5.809553  3.674587  5.577503
#
# [5 rows x 16384 columns]

# %%
data['cluster'].replace([1, 2],[0, 1],inplace=True)
data.shape
# Out:
# (541, 16384)

# %%
selected_genes = pd.read_csv('cleaned/boruta.csv')
selected_genes = selected_genes.values.tolist()
selected_genes = list(itertools.chain(*selected_genes))
len(selected_genes)
# Out:
# 300

# %%
# retrieving proper columns
X = data.loc[:, selected_genes]
y = data['cluster'].values
# scaling the data
scalar = MinMaxScaler()
x_scaled = scalar.fit_transform(X)
# splitting data (20% test, 80% train)
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2)
sm = SMOTE()
X_train, y_train = sm.fit_sample(X_train, y_train)

# %% [markdown]
# # Confusion Matrix Plotting Function

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True, cbar=True):
    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    fig = plt.figure(figsize=(4, 3), dpi=200)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names)
        plt.yticks(tick_marks, target_names, rotation=90, verticalalignment='center')
#         plt.yticks([], ['', ''])

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    if cbar:
        plt.colorbar()

    plt.tight_layout()
    plt.ylabel('True')
    plt.xlabel('Predicted\naccuracy={:0.3f}; misclass={:0.3f}'.format(accuracy, misclass))
    plt.show()

    return fig

# %% [markdown]
# # 5 Hidden Layers

# %%
def hidden5(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 5 hidden layers
    for i in range(5):
        model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model5 = KerasClassifier(build_fn=hidden5, epochs=25, batch_size=16)

# %%
history5 = model5.fit(X_train, y_train, validation_data=(X_test,y_test), shuffle=True)
y_pred5 = model5.predict(X_test)
# Out:
# Train on 564 samples, validate on 109 samples
# Epoch 1/25
# 564/564 [==============================] - 4s 7ms/sample - loss: 1.2639 - accuracy: 0.6560 - val_loss: 1.1630 - val_accuracy: 0.8532
# Epoch 2/25
# 564/564 [==============================] - 0s 797us/sample - loss: 1.1445 - accuracy: 0.7163 - val_loss: 1.0962 - val_accuracy: 0.8991
# Epoch 3/25
# 564/564 [==============================] - 0s 797us/sample - loss: 1.0671 - accuracy: 0.7624 - val_loss: 1.0172 - val_accuracy: 0.8716
# Epoch 4/25
# 564/564 [==============================] - 0s 790us/sample - loss: 1.0863 - accuracy: 0.7589 - val_loss: 0.9762 - val_accuracy: 0.8899
# Epoch 5/25
# 564/564 [==============================] - 0s 791us/sample - loss: 1.0739 - accuracy: 0.7730 - val_loss: 0.9519 - val_accuracy: 0.8807
# Epoch 6/25
# 564/564 [==============================] - 0s 789us/sample - loss: 1.0612 - accuracy: 0.7766 - val_loss: 0.9365 - val_accuracy: 0.8716
# Epoch 7/25
# 564/564 [==============================] - 0s 797us/sample - loss: 1.0215 - accuracy: 0.7677 - val_loss: 0.9779 - val_accuracy: 0.8532
# Epoch 8/25
# 564/564 [==============================] - 0s 789us/sample - loss: 1.0355 - accuracy: 0.7695 - val_loss: 0.9303 - val_accuracy: 0.8807
# Epoch 9/25
# 564/564 [==============================] - 0s 806us/sample - loss: 0.9770 - accuracy: 0.8156 - val_loss: 0.9830 - val_accuracy: 0.8440
# Epoch 10/25
# 564/564 [==============================] - 0s 815us/sample - loss: 0.9627 - accuracy: 0.8298 - val_loss: 0.8779 - val_accuracy: 0.8716
# Epoch 11/25
# 564/564 [==============================] - 0s 810us/sample - loss: 0.9891 - accuracy: 0.7979 - val_loss: 0.8703 - val_accuracy: 0.8807
# Epoch 12/25
# 564/564 [==============================] - 0s 794us/sample - loss: 0.9675 - accuracy: 0.8121 - val_loss: 0.9118 - val_accuracy: 0.8807
# Epoch 13/25
# 564/564 [==============================] - 0s 817us/sample - loss: 0.9975 - accuracy: 0.7908 - val_loss: 0.8708 - val_accuracy: 0.8899
# Epoch 14/25
# 564/564 [==============================] - 0s 863us/sample - loss: 0.9984 - accuracy: 0.7979 - val_loss: 0.8402 - val_accuracy: 0.8899
# Epoch 15/25
# 564/564 [==============================] - 1s 901us/sample - loss: 0.9676 - accuracy: 0.8103 - val_loss: 0.8268 - val_accuracy: 0.8899
# Epoch 16/25
# 564/564 [==============================] - 1s 907us/sample - loss: 0.9751 - accuracy: 0.8032 - val_loss: 0.8389 - val_accuracy: 0.8899
# Epoch 17/25
# 564/564 [==============================] - 0s 875us/sample - loss: 0.9146 - accuracy: 0.8493 - val_loss: 0.8275 - val_accuracy: 0.8899
# Epoch 18/25
# 564/564 [==============================] - 0s 870us/sample - loss: 0.9258 - accuracy: 0.8422 - val_loss: 0.9748 - val_accuracy: 0.8807
# Epoch 19/25
# 564/564 [==============================] - 0s 857us/sample - loss: 0.9870 - accuracy: 0.8103 - val_loss: 0.8570 - val_accuracy: 0.8716
# Epoch 20/25
# 564/564 [==============================] - 0s 845us/sample - loss: 0.9663 - accuracy: 0.8103 - val_loss: 0.8470 - val_accuracy: 0.8807
# Epoch 21/25
# 564/564 [==============================] - 0s 857us/sample - loss: 0.9629 - accuracy: 0.8298 - val_loss: 0.8642 - val_accuracy: 0.8807
# Epoch 22/25
# 564/564 [==============================] - 0s 882us/sample - loss: 0.9370 - accuracy: 0.8440 - val_loss: 0.8860 - val_accuracy: 0.8716
# Epoch 23/25
# 564/564 [==============================] - 0s 867us/sample - loss: 0.8862 - accuracy: 0.8582 - val_loss: 0.8625 - val_accuracy: 0.8624
# Epoch 24/25
# 564/564 [==============================] - 0s 871us/sample - loss: 0.9459 - accuracy: 0.8174 - val_loss: 0.9365 - val_accuracy: 0.8349
# Epoch 25/25
# 564/564 [==============================] - 0s 885us/sample - loss: 0.9085 - accuracy: 0.8404 - val_loss: 0.9609 - val_accuracy: 0.8073

# %%
print(classification_report(y_test, y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.74      0.83        70
#            1       0.67      0.92      0.77        39
#
#     accuracy                           0.81       109
#    macro avg       0.81      0.83      0.80       109
# weighted avg       0.85      0.81      0.81       109

# %%
plt.plot(history5.history['accuracy'])
plt.plot(history5.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.ylim(0, 1)
plt.xlim(0, 25)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred5)
plt.rcParams.update({'font.size': 10})
plot_confusion_matrix(cm, ['responder', 'non-responder'], title='', normalize=False)

# %%
model5.model.save('models/')
# Out:
# WARNING:tensorflow:From /Users/eddieguo/anaconda3/envs/fixed_comp/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: models/assets

# %% [markdown]
# # 1 Hidden Layer

# %%
def hidden1(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 1 hidden layer
    model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model1 = KerasClassifier(build_fn=hidden1, epochs=25, batch_size=16)

# %%
history1 = model1.fit(X_train, y_train, validation_data=(X_test,y_test), shuffle=True)
y_pred1 = model1.predict(X_test)
# Out:
# Train on 564 samples, validate on 109 samples
# Epoch 1/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 0.6777 - accuracy: 0.7482 - val_loss: 0.6305 - val_accuracy: 0.8899
# Epoch 2/25
# 564/564 [==============================] - 0s 330us/sample - loss: 0.5843 - accuracy: 0.8050 - val_loss: 0.5930 - val_accuracy: 0.8991
# Epoch 3/25
# 564/564 [==============================] - 0s 332us/sample - loss: 0.5455 - accuracy: 0.8262 - val_loss: 0.5478 - val_accuracy: 0.9083
# Epoch 4/25
# 564/564 [==============================] - 0s 330us/sample - loss: 0.5244 - accuracy: 0.8191 - val_loss: 0.5188 - val_accuracy: 0.8991
# Epoch 5/25
# 564/564 [==============================] - 0s 325us/sample - loss: 0.5136 - accuracy: 0.8422 - val_loss: 0.4924 - val_accuracy: 0.9083
# Epoch 6/25
# 564/564 [==============================] - 0s 326us/sample - loss: 0.5040 - accuracy: 0.8546 - val_loss: 0.4866 - val_accuracy: 0.8991
# Epoch 7/25
# 564/564 [==============================] - 0s 325us/sample - loss: 0.4890 - accuracy: 0.8511 - val_loss: 0.4715 - val_accuracy: 0.9083
# Epoch 8/25
# 564/564 [==============================] - 0s 331us/sample - loss: 0.4516 - accuracy: 0.8759 - val_loss: 0.4628 - val_accuracy: 0.9083
# Epoch 9/25
# 564/564 [==============================] - 0s 325us/sample - loss: 0.4641 - accuracy: 0.8652 - val_loss: 0.4777 - val_accuracy: 0.8899
# Epoch 10/25
# 564/564 [==============================] - 0s 336us/sample - loss: 0.4501 - accuracy: 0.8723 - val_loss: 0.4205 - val_accuracy: 0.9083
# Epoch 11/25
# 564/564 [==============================] - 0s 345us/sample - loss: 0.4187 - accuracy: 0.8901 - val_loss: 0.4746 - val_accuracy: 0.8899
# Epoch 12/25
# 564/564 [==============================] - 0s 342us/sample - loss: 0.4303 - accuracy: 0.8918 - val_loss: 0.4316 - val_accuracy: 0.8991
# Epoch 13/25
# 564/564 [==============================] - 0s 347us/sample - loss: 0.4207 - accuracy: 0.8848 - val_loss: 0.4761 - val_accuracy: 0.8899
# Epoch 14/25
# 564/564 [==============================] - 0s 341us/sample - loss: 0.4233 - accuracy: 0.8954 - val_loss: 0.4959 - val_accuracy: 0.8991
# Epoch 15/25
# 564/564 [==============================] - 0s 348us/sample - loss: 0.4350 - accuracy: 0.8848 - val_loss: 0.4544 - val_accuracy: 0.9083
# Epoch 16/25
# 564/564 [==============================] - 0s 340us/sample - loss: 0.3992 - accuracy: 0.8972 - val_loss: 0.4527 - val_accuracy: 0.8899
# Epoch 17/25
# 564/564 [==============================] - 0s 337us/sample - loss: 0.4397 - accuracy: 0.8670 - val_loss: 0.4526 - val_accuracy: 0.8807
# Epoch 18/25
# 564/564 [==============================] - 0s 339us/sample - loss: 0.3829 - accuracy: 0.8989 - val_loss: 0.4797 - val_accuracy: 0.9083
# Epoch 19/25
# 564/564 [==============================] - 0s 332us/sample - loss: 0.3796 - accuracy: 0.9220 - val_loss: 0.4348 - val_accuracy: 0.8899
# Epoch 20/25
# 564/564 [==============================] - 0s 335us/sample - loss: 0.3946 - accuracy: 0.9007 - val_loss: 0.4303 - val_accuracy: 0.9083
# Epoch 21/25
# 564/564 [==============================] - 0s 347us/sample - loss: 0.3652 - accuracy: 0.9060 - val_loss: 0.4932 - val_accuracy: 0.8807
# Epoch 22/25
# 564/564 [==============================] - 0s 347us/sample - loss: 0.3642 - accuracy: 0.9167 - val_loss: 0.5612 - val_accuracy: 0.8440
# Epoch 23/25
# 564/564 [==============================] - 0s 343us/sample - loss: 0.3422 - accuracy: 0.9291 - val_loss: 0.4457 - val_accuracy: 0.8899
# Epoch 24/25
# 564/564 [==============================] - 0s 347us/sample - loss: 0.3481 - accuracy: 0.9220 - val_loss: 0.4598 - val_accuracy: 0.8807
# Epoch 25/25
# 564/564 [==============================] - 0s 341us/sample - loss: 0.3357 - accuracy: 0.9326 - val_loss: 0.4450 - val_accuracy: 0.8991

# %%
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92        70
#            1       0.87      0.85      0.86        39
#
#     accuracy                           0.90       109
#    macro avg       0.89      0.89      0.89       109
# weighted avg       0.90      0.90      0.90       109

# %%
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0, 1)
plt.xlim(0, 25)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred1)
plot_confusion_matrix(cm, ['responder', 'non-responder'], title='', normalize=False)

# %%
model1.model.save('models/')
# Out:
# INFO:tensorflow:Assets written to: models/assets

# %% [markdown]
# # 10 Hidden Layers

# %%
def hidden10(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 10 hidden layers
    for i in range(10):
        model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model10 = KerasClassifier(build_fn=hidden10, epochs=25, batch_size=16)

# %%
history10 = model10.fit(X_train, y_train, validation_data=(X_test, y_test), shuffle=True)
y_pred10 = model10.predict(X_test)
# Out:
# Train on 564 samples, validate on 109 samples
# Epoch 1/25
# 564/564 [==============================] - 7s 12ms/sample - loss: 2.0009 - accuracy: 0.5071 - val_loss: 2.0206 - val_accuracy: 0.4679
# Epoch 2/25
# 564/564 [==============================] - 1s 1ms/sample - loss: 2.1712 - accuracy: 0.5035 - val_loss: 2.1675 - val_accuracy: 0.2202
# Epoch 3/25
# 564/564 [==============================] - 1s 1ms/sample - loss: 2.1499 - accuracy: 0.5230 - val_loss: 3.4816 - val_accuracy: 0.3119
# Epoch 4/25
# 564/564 [==============================] - 1s 1ms/sample - loss: 2.5600 - accuracy: 0.5904 - val_loss: 2.2793 - val_accuracy: 0.7523
# Epoch 5/25
# 564/564 [==============================] - 1s 1ms/sample - loss: 2.5517 - accuracy: 0.6046 - val_loss: 2.2236 - val_accuracy: 0.8165
# Epoch 6/25
# 564/564 [==============================] - 1s 1ms/sample - loss: 2.5053 - accuracy: 0.6188 - val_loss: 2.1795 - val_accuracy: 0.8899
# Epoch 7/25
# 564/564 [==============================] - 1s 1ms/sample - loss: 2.4972 - accuracy: 0.6454 - val_loss: 2.1591 - val_accuracy: 0.8899
# Epoch 8/25
# 564/564 [==============================] - 1s 1ms/sample - loss: 2.4597 - accuracy: 0.6613 - val_loss: 2.1918 - val_accuracy: 0.8807
# Epoch 9/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.4160 - accuracy: 0.6968 - val_loss: 2.1851 - val_accuracy: 0.8807
# Epoch 10/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.4354 - accuracy: 0.6897 - val_loss: 2.1840 - val_accuracy: 0.8991
# Epoch 11/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3744 - accuracy: 0.7287 - val_loss: 2.2425 - val_accuracy: 0.8624
# Epoch 12/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3995 - accuracy: 0.7252 - val_loss: 2.1855 - val_accuracy: 0.8807
# Epoch 13/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.4089 - accuracy: 0.7004 - val_loss: 2.2132 - val_accuracy: 0.8807
# Epoch 14/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.4026 - accuracy: 0.7252 - val_loss: 2.1732 - val_accuracy: 0.8899
# Epoch 15/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3702 - accuracy: 0.7518 - val_loss: 2.1247 - val_accuracy: 0.8991
# Epoch 16/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3670 - accuracy: 0.7429 - val_loss: 2.4662 - val_accuracy: 0.5872
# Epoch 17/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3775 - accuracy: 0.7376 - val_loss: 2.1542 - val_accuracy: 0.8807
# Epoch 18/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3430 - accuracy: 0.7465 - val_loss: 2.1457 - val_accuracy: 0.9083
# Epoch 19/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3502 - accuracy: 0.7624 - val_loss: 2.1756 - val_accuracy: 0.8807
# Epoch 20/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3722 - accuracy: 0.7677 - val_loss: 2.3275 - val_accuracy: 0.8349
# Epoch 21/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3620 - accuracy: 0.7429 - val_loss: 2.1853 - val_accuracy: 0.8899
# Epoch 22/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.4103 - accuracy: 0.7465 - val_loss: 2.2307 - val_accuracy: 0.8899
# Epoch 23/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.4050 - accuracy: 0.7411 - val_loss: 2.2079 - val_accuracy: 0.8807
# Epoch 24/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.4006 - accuracy: 0.7376 - val_loss: 2.1969 - val_accuracy: 0.8899
# Epoch 25/25
# 564/564 [==============================] - 1s 2ms/sample - loss: 2.3783 - accuracy: 0.7535 - val_loss: 2.1817 - val_accuracy: 0.8899

# %%
print(classification_report(y_test, y_pred10))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92        70
#            1       0.86      0.82      0.84        39
#
#     accuracy                           0.89       109
#    macro avg       0.88      0.87      0.88       109
# weighted avg       0.89      0.89      0.89       109

# %%
print(confusion_matrix(y_test, y_pred10))
# Out:
# [[65  5]
#  [ 7 32]]

# %%
plt.plot(history10.history['accuracy'])
plt.plot(history10.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0, 1)
plt.xlim(0, 25)
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred10)
plot_confusion_matrix(cm, ['responder', 'non-responder'], title='', normalize=False)

# %%
model10.model.save('models/')
# Out:
# INFO:tensorflow:Assets written to: models/assets
