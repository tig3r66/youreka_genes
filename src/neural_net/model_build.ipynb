# %%
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# for data scaling and splitting
from sklearn.preprocessing import MinMaxScaler 
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
# for neural net
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras import regularizers
# for evaluation
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv("data/combined_expression.csv")
data.head()
# Out:
#    CELL_LINE_NAME  cluster    TSPAN6      TNMD       DPM1     SCYL3  C1orf112  \
# 0         1240123        2  8.319417  3.111183   9.643558  4.757258  3.919757
# 1         1240131        1  7.611268  2.704739  10.276079  3.650299  3.481567
# 2         1240132        1  7.678658  2.845781  10.180954  3.573048  3.431235
# 3         1240134        1  3.265063  3.063746  10.490285  3.340791  3.676912
# 4         1240140        1  7.090138  2.988043  10.264692  4.119555  3.432585
#
#         FGR       CFH     FUCA2  ...   C6orf10   TMEM225    NOTCH4      PBX2  \
# 0  3.602185  3.329644  9.076950  ...  3.085394  3.462811  3.339030  4.614897
# 1  3.145538  3.565127  7.861068  ...  2.801456  2.985889  3.180068  5.415729
# 2  3.090781  4.116643  8.121190  ...  2.934962  2.952937  3.164655  5.707506
# 3  3.512821  3.873922  8.790851  ...  3.041839  3.398847  3.106710  5.773963
# 4  3.308033  3.318371  6.927761  ...  3.028787  3.225982  3.275820  5.334283
#
#        AGER      RNF5    AGPAT1    DFNB59     PRRT1     FKBPL
# 0  3.395845  3.419193  3.971646  3.729310  3.320022  6.447316
# 1  3.299858  3.028414  3.877889  3.911516  3.379405  4.729557
# 2  3.434295  2.961345  4.272194  3.085696  3.002557  5.653588
# 3  3.412641  3.136110  4.422262  3.522122  3.509437  5.953242
# 4  3.864678  3.259242  3.840581  5.809553  3.674587  5.577503
#
# [5 rows x 16384 columns]

# %%
data['cluster'].replace([1, 2],[0, 1],inplace=True)
data.shape
# Out:
# (541, 16384)

# %%
selected_genes = pd.read_csv('cleaned/boruta.csv')
selected_genes = selected_genes.values.tolist()
selected_genes = list(itertools.chain(*selected_genes))
len(selected_genes)
# Out:
# 300

# %%
# retrieving proper columns
X = data.loc[:, selected_genes]
y = data['cluster'].values
# scaling the data
scalar = MinMaxScaler()
x_scaled = scalar.fit_transform(X)
# splitting data (20% test, 80% train)
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2)
sm = SMOTE()
X_train, y_train = sm.fit_sample(X_train, y_train)

# %% [markdown]
# # Confusion Matrix Plotting Function

# %%
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True, cbar=True):
    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    fig = plt.figure(figsize=(4, 3), dpi=200)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names)
        plt.yticks(tick_marks, target_names, rotation=90, verticalalignment='center')
#         plt.yticks([], ['', ''])

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    if cbar:
        plt.colorbar()

    plt.tight_layout()
    plt.ylabel('True')
    plt.xlabel('Predicted\naccuracy={:0.3f}; misclass={:0.3f}'.format(accuracy, misclass))
    plt.show()

    return fig

# %% [markdown]
# # 1 Hidden Layer

# %%
def hidden1(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 1 hidden layer
    model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model1 = KerasClassifier(build_fn=hidden1, epochs=25, batch_size=16)

# %%
history1 = model1.fit(X_train, y_train, validation_data=(X_test,y_test), shuffle=True)
y_pred1 = model1.predict(X_test)
# Out:
# Train on 562 samples, validate on 109 samples
# Epoch 1/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 0.5764 - accuracy: 0.8221 - val_loss: 0.5967 - val_accuracy: 0.8532
# Epoch 2/25
# 562/562 [==============================] - 0s 323us/sample - loss: 0.5695 - accuracy: 0.8078 - val_loss: 0.5775 - val_accuracy: 0.8807
# Epoch 3/25
# 562/562 [==============================] - 0s 345us/sample - loss: 0.4827 - accuracy: 0.8577 - val_loss: 0.5763 - val_accuracy: 0.8532
# Epoch 4/25
# 562/562 [==============================] - 0s 345us/sample - loss: 0.4728 - accuracy: 0.8719 - val_loss: 0.5668 - val_accuracy: 0.8532
# Epoch 5/25
# 562/562 [==============================] - 0s 337us/sample - loss: 0.4583 - accuracy: 0.8737 - val_loss: 0.5522 - val_accuracy: 0.8440
# Epoch 6/25
# 562/562 [==============================] - 0s 337us/sample - loss: 0.4332 - accuracy: 0.8915 - val_loss: 0.6008 - val_accuracy: 0.8073
# Epoch 7/25
# 562/562 [==============================] - 0s 336us/sample - loss: 0.4484 - accuracy: 0.8826 - val_loss: 0.5470 - val_accuracy: 0.8624
# Epoch 8/25
# 562/562 [==============================] - 0s 336us/sample - loss: 0.4370 - accuracy: 0.8737 - val_loss: 0.5183 - val_accuracy: 0.8532
# Epoch 9/25
# 562/562 [==============================] - 0s 334us/sample - loss: 0.4356 - accuracy: 0.8897 - val_loss: 0.5271 - val_accuracy: 0.8532
# Epoch 10/25
# 562/562 [==============================] - 0s 336us/sample - loss: 0.3985 - accuracy: 0.9146 - val_loss: 0.6242 - val_accuracy: 0.7798
# Epoch 11/25
# 562/562 [==============================] - 0s 339us/sample - loss: 0.4258 - accuracy: 0.8879 - val_loss: 0.5360 - val_accuracy: 0.8349
# Epoch 12/25
# 562/562 [==============================] - 0s 337us/sample - loss: 0.3897 - accuracy: 0.8986 - val_loss: 0.5306 - val_accuracy: 0.8532
# Epoch 13/25
# 562/562 [==============================] - 0s 395us/sample - loss: 0.3847 - accuracy: 0.9146 - val_loss: 0.5231 - val_accuracy: 0.8624
# Epoch 14/25
# 562/562 [==============================] - 0s 424us/sample - loss: 0.4044 - accuracy: 0.9075 - val_loss: 0.5643 - val_accuracy: 0.8165
# Epoch 15/25
# 562/562 [==============================] - 0s 399us/sample - loss: 0.3845 - accuracy: 0.9164 - val_loss: 0.5558 - val_accuracy: 0.8532
# Epoch 16/25
# 562/562 [==============================] - 0s 384us/sample - loss: 0.3705 - accuracy: 0.9128 - val_loss: 0.5371 - val_accuracy: 0.8716
# Epoch 17/25
# 562/562 [==============================] - 0s 379us/sample - loss: 0.3555 - accuracy: 0.9181 - val_loss: 0.5341 - val_accuracy: 0.8624
# Epoch 18/25
# 562/562 [==============================] - 0s 382us/sample - loss: 0.3707 - accuracy: 0.9199 - val_loss: 0.5970 - val_accuracy: 0.7982
# Epoch 19/25
# 562/562 [==============================] - 0s 442us/sample - loss: 0.3742 - accuracy: 0.9164 - val_loss: 0.5410 - val_accuracy: 0.8349
# Epoch 20/25
# 562/562 [==============================] - 0s 363us/sample - loss: 0.3728 - accuracy: 0.9039 - val_loss: 0.6030 - val_accuracy: 0.7890
# Epoch 21/25
# 562/562 [==============================] - 0s 346us/sample - loss: 0.3586 - accuracy: 0.9128 - val_loss: 0.5480 - val_accuracy: 0.8440
# Epoch 22/25
# 562/562 [==============================] - 0s 346us/sample - loss: 0.3554 - accuracy: 0.9253 - val_loss: 0.5611 - val_accuracy: 0.8624
# Epoch 23/25
# 562/562 [==============================] - 0s 348us/sample - loss: 0.3416 - accuracy: 0.9306 - val_loss: 0.5565 - val_accuracy: 0.8257
# Epoch 24/25
# 562/562 [==============================] - 0s 349us/sample - loss: 0.3721 - accuracy: 0.9199 - val_loss: 0.5385 - val_accuracy: 0.8624
# Epoch 25/25
# 562/562 [==============================] - 0s 345us/sample - loss: 0.3534 - accuracy: 0.9199 - val_loss: 0.5492 - val_accuracy: 0.8440

# %%
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.88        71
#            1       0.82      0.71      0.76        38
#
#     accuracy                           0.84       109
#    macro avg       0.84      0.81      0.82       109
# weighted avg       0.84      0.84      0.84       109

# %%
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0, 1)
plt.xlim(0, 25)
plt.show()

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
cm = confusion_matrix(y_test, y_pred1)
plot_confusion_matrix(cm, ['responder', 'non-responder'], title='', normalize=False)

# %%
model1.model.save('models/hidden1/')
# Out:
# WARNING:tensorflow:From /Users/eddieguo/anaconda3/envs/fixed_comp/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: models/hidden1/assets

# %% [markdown]
# # 5 Hidden Layers

# %%
def hidden5(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 5 hidden layers
    for i in range(5):
        model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model5 = KerasClassifier(build_fn=hidden5, epochs=25, batch_size=16)

# %%
history5 = model5.fit(X_train, y_train, validation_data=(X_test,y_test), shuffle=True)
y_pred5 = model5.predict(X_test)
# Out:
# Train on 562 samples, validate on 109 samples
# Epoch 1/25
# 562/562 [==============================] - 4s 7ms/sample - loss: 1.2537 - accuracy: 0.6495 - val_loss: 8.9046 - val_accuracy: 0.3394
# Epoch 2/25
# 562/562 [==============================] - 0s 838us/sample - loss: 1.8290 - accuracy: 0.6851 - val_loss: 1.9235 - val_accuracy: 0.4679
# Epoch 3/25
# 562/562 [==============================] - 0s 861us/sample - loss: 1.8034 - accuracy: 0.7384 - val_loss: 1.7294 - val_accuracy: 0.7706
# Epoch 4/25
# 562/562 [==============================] - 0s 849us/sample - loss: 1.7146 - accuracy: 0.7722 - val_loss: 1.7627 - val_accuracy: 0.7339
# Epoch 5/25
# 562/562 [==============================] - 0s 849us/sample - loss: 1.6863 - accuracy: 0.7972 - val_loss: 1.7069 - val_accuracy: 0.8532
# Epoch 6/25
# 562/562 [==============================] - 0s 854us/sample - loss: 1.6980 - accuracy: 0.8025 - val_loss: 1.6842 - val_accuracy: 0.8624
# Epoch 7/25
# 562/562 [==============================] - 0s 862us/sample - loss: 1.6744 - accuracy: 0.7989 - val_loss: 1.6173 - val_accuracy: 0.8440
# Epoch 8/25
# 562/562 [==============================] - 0s 862us/sample - loss: 1.6606 - accuracy: 0.8292 - val_loss: 1.6214 - val_accuracy: 0.8349
# Epoch 9/25
# 562/562 [==============================] - 0s 859us/sample - loss: 1.6609 - accuracy: 0.8114 - val_loss: 1.6069 - val_accuracy: 0.8349
# Epoch 10/25
# 562/562 [==============================] - 0s 868us/sample - loss: 1.6693 - accuracy: 0.8132 - val_loss: 1.6503 - val_accuracy: 0.8165
# Epoch 11/25
# 562/562 [==============================] - 0s 866us/sample - loss: 1.6044 - accuracy: 0.8434 - val_loss: 71.0531 - val_accuracy: 0.3486
# Epoch 12/25
# 562/562 [==============================] - 0s 889us/sample - loss: 2.2474 - accuracy: 0.8274 - val_loss: 2.2433 - val_accuracy: 0.8257
# Epoch 13/25
# 562/562 [==============================] - 0s 871us/sample - loss: 2.2371 - accuracy: 0.7972 - val_loss: 2.2142 - val_accuracy: 0.8349
# Epoch 14/25
# 562/562 [==============================] - 0s 872us/sample - loss: 2.2574 - accuracy: 0.8007 - val_loss: 2.4667 - val_accuracy: 0.6514
# Epoch 15/25
# 562/562 [==============================] - 0s 881us/sample - loss: 2.2003 - accuracy: 0.8381 - val_loss: 2.2128 - val_accuracy: 0.8532
# Epoch 16/25
# 562/562 [==============================] - 0s 883us/sample - loss: 2.2611 - accuracy: 0.8114 - val_loss: 2.2190 - val_accuracy: 0.8349
# Epoch 17/25
# 562/562 [==============================] - 1s 899us/sample - loss: 2.2183 - accuracy: 0.8256 - val_loss: 2.1852 - val_accuracy: 0.8532
# Epoch 18/25
# 562/562 [==============================] - 1s 918us/sample - loss: 2.1943 - accuracy: 0.8327 - val_loss: 2.1876 - val_accuracy: 0.8349
# Epoch 19/25
# 562/562 [==============================] - 1s 917us/sample - loss: 2.1617 - accuracy: 0.8434 - val_loss: 2.1663 - val_accuracy: 0.8716
# Epoch 20/25
# 562/562 [==============================] - 1s 950us/sample - loss: 2.1885 - accuracy: 0.8363 - val_loss: 2.1979 - val_accuracy: 0.8624
# Epoch 21/25
# 562/562 [==============================] - 1s 950us/sample - loss: 2.2242 - accuracy: 0.8381 - val_loss: 2.1796 - val_accuracy: 0.8716
# Epoch 22/25
# 562/562 [==============================] - 1s 945us/sample - loss: 2.1786 - accuracy: 0.8256 - val_loss: 2.1948 - val_accuracy: 0.8349
# Epoch 23/25
# 562/562 [==============================] - 1s 963us/sample - loss: 2.1647 - accuracy: 0.8523 - val_loss: 2.1704 - val_accuracy: 0.8716
# Epoch 24/25
# 562/562 [==============================] - 1s 980us/sample - loss: 2.1869 - accuracy: 0.8292 - val_loss: 2.1742 - val_accuracy: 0.8532
# Epoch 25/25
# 562/562 [==============================] - 1s 981us/sample - loss: 2.1779 - accuracy: 0.8488 - val_loss: 2.1652 - val_accuracy: 0.8624

# %%
print(classification_report(y_test, y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90        71
#            1       0.85      0.74      0.79        38
#
#     accuracy                           0.86       109
#    macro avg       0.86      0.83      0.84       109
# weighted avg       0.86      0.86      0.86       109

# %%
plt.plot(history5.history['accuracy'])
plt.plot(history5.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')
plt.ylim(0, 1)
plt.xlim(0, 25)
plt.show()

# %%
plt.plot(history5.history['loss'])
plt.plot(history5.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
cm = confusion_matrix(y_test, y_pred5)
plt.rcParams.update({'font.size': 10})
plot_confusion_matrix(cm, ['responder', 'non-responder'], title='', normalize=False)

# %%
model5.model.save('models/hidden5/')
# Out:
# INFO:tensorflow:Assets written to: models/hidden5/assets

# %% [markdown]
# # 10 Hidden Layers

# %%
def hidden10(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 10 hidden layers
    for i in range(10):
        model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model10 = KerasClassifier(build_fn=hidden10, epochs=25, batch_size=16)

# %%
history10 = model10.fit(X_train, y_train, validation_data=(X_test, y_test), shuffle=True)
y_pred10 = model10.predict(X_test)
# Out:
# Train on 562 samples, validate on 109 samples
# Epoch 1/25
# 562/562 [==============================] - 7s 12ms/sample - loss: 2.0021 - accuracy: 0.5160 - val_loss: 3.5740 - val_accuracy: 0.7339
# Epoch 2/25
# 562/562 [==============================] - 1s 1ms/sample - loss: 3.7971 - accuracy: 0.5285 - val_loss: 3.5020 - val_accuracy: 0.8899
# Epoch 3/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 3.7258 - accuracy: 0.5783 - val_loss: 4.3485 - val_accuracy: 0.3486
# Epoch 4/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 3.8765 - accuracy: 0.6690 - val_loss: 8923.0367 - val_accuracy: 0.6514
# Epoch 5/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1611.5110 - accuracy: 0.5196 - val_loss: 1621.4976 - val_accuracy: 0.6514
# Epoch 6/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1609.8736 - accuracy: 0.5694 - val_loss: 1610.2692 - val_accuracy: 0.6514
# Epoch 7/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1607.5602 - accuracy: 0.5783 - val_loss: 1608.4959 - val_accuracy: 0.3486
# Epoch 8/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1605.3366 - accuracy: 0.6139 - val_loss: 1604.1198 - val_accuracy: 0.6514
# Epoch 9/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1603.0573 - accuracy: 0.6050 - val_loss: 1602.8203 - val_accuracy: 0.6881
# Epoch 10/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1601.8490 - accuracy: 0.6423 - val_loss: 1601.6319 - val_accuracy: 0.7431
# Epoch 11/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1599.7816 - accuracy: 0.6299 - val_loss: 1606.4035 - val_accuracy: 0.2752
# Epoch 12/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1597.5564 - accuracy: 0.6673 - val_loss: 1596.1708 - val_accuracy: 0.8257
# Epoch 13/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1595.2393 - accuracy: 0.6886 - val_loss: 1602.7425 - val_accuracy: 0.6422
# Epoch 14/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1597.8481 - accuracy: 0.6868 - val_loss: 1596.5034 - val_accuracy: 0.8073
# Epoch 15/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1595.5285 - accuracy: 0.7206 - val_loss: 1594.2292 - val_accuracy: 0.8257
# Epoch 16/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1593.2901 - accuracy: 0.6957 - val_loss: 1591.9368 - val_accuracy: 0.8073
# Epoch 17/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1591.0064 - accuracy: 0.6886 - val_loss: 1589.6469 - val_accuracy: 0.7982
# Epoch 18/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1588.6824 - accuracy: 0.7242 - val_loss: 1587.3538 - val_accuracy: 0.8349
# Epoch 19/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1586.3961 - accuracy: 0.7189 - val_loss: 1590.9124 - val_accuracy: 0.6239
# Epoch 20/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1585.1503 - accuracy: 0.7206 - val_loss: 1583.8466 - val_accuracy: 0.8073
# Epoch 21/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1582.8903 - accuracy: 0.7367 - val_loss: 1581.5485 - val_accuracy: 0.8349
# Epoch 22/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1580.5589 - accuracy: 0.7687 - val_loss: 1579.2907 - val_accuracy: 0.8165
# Epoch 23/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1578.3116 - accuracy: 0.7224 - val_loss: 1577.0206 - val_accuracy: 0.8257
# Epoch 24/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1576.0407 - accuracy: 0.7224 - val_loss: 1574.7358 - val_accuracy: 0.8257
# Epoch 25/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 1573.7645 - accuracy: 0.7544 - val_loss: 1572.4786 - val_accuracy: 0.8349

# %%
print(classification_report(y_test, y_pred10))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88        71
#            1       0.79      0.71      0.75        38
#
#     accuracy                           0.83       109
#    macro avg       0.82      0.81      0.81       109
# weighted avg       0.83      0.83      0.83       109

# %%
print(confusion_matrix(y_test, y_pred10))
# Out:
# [[64  7]
#  [11 27]]

# %%
plt.plot(history10.history['accuracy'])
plt.plot(history10.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0, 1)
plt.xlim(0, 25)
plt.show()

# %%
plt.plot(history10.history['loss'])
plt.plot(history10.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
model10.model.save('models/hidden10/')
# Out:
# INFO:tensorflow:Assets written to: models/hidden10/assets

# %% [markdown]
# # 15 Hidden Layers

# %%
def hidden15(optimizer='sgd', init='normal', dropout=0.3, neurons=100):
    model = Sequential()
    hidden_layers = len(selected_genes)
    # add 15 hidden layers
    for i in range(15):
        model.add(Dense(neurons, activation='relu', kernel_regularizer=regularizers.l2(1e-3)))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

    model.add(Dense(1, activation='sigmoid'))
    # compiling
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model15 = KerasClassifier(build_fn=hidden15, epochs=25, batch_size=16)

# %%
history15 = model15.fit(X_train, y_train, validation_data=(X_test, y_test), shuffle=True)
y_pred15 = model15.predict(X_test)
# Out:
# Train on 562 samples, validate on 109 samples
# Epoch 1/25
# 562/562 [==============================] - 10s 17ms/sample - loss: 2.5493 - accuracy: 0.4804 - val_loss: 993441894878271099633664.0000 - val_accuracy: 0.6514
# Epoch 2/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 101220.9535 - accuracy: 0.5730 - val_loss: 101152.3965 - val_accuracy: 0.6514
# Epoch 3/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 101075.3227 - accuracy: 0.5641 - val_loss: 101005.8271 - val_accuracy: 0.3486
# Epoch 4/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 100930.3212 - accuracy: 0.6068 - val_loss: 102007.8501 - val_accuracy: 0.1376
# Epoch 5/25
# 562/562 [==============================] - 1s 2ms/sample - loss: 100875.7955 - accuracy: 0.5979 - val_loss: 100799.4933 - val_accuracy: 0.3486
# Epoch 6/25
# 562/562 [==============================] - 1s 3ms/sample - loss: 100730.5961 - accuracy: 0.5996 - val_loss: 100654.1537 - val_accuracy: 0.8991
# Epoch 7/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 100585.6064 - accuracy: 0.6388 - val_loss: 100609.0425 - val_accuracy: 0.3486
# Epoch 8/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 100445.2275 - accuracy: 0.6530 - val_loss: 100369.0631 - val_accuracy: 0.8257
# Epoch 9/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 100300.7014 - accuracy: 0.6512 - val_loss: 100225.7608 - val_accuracy: 0.7339
# Epoch 10/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 100157.3816 - accuracy: 0.6441 - val_loss: 100081.4016 - val_accuracy: 0.7982
# Epoch 11/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 100013.2121 - accuracy: 0.6779 - val_loss: 99937.3333 - val_accuracy: 0.8440
# Epoch 12/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 99869.3223 - accuracy: 0.6815 - val_loss: 99794.2450 - val_accuracy: 0.8991
# Epoch 13/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 99726.0775 - accuracy: 0.6868 - val_loss: 99650.3986 - val_accuracy: 0.8532
# Epoch 14/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 99582.5364 - accuracy: 0.6940 - val_loss: 99507.0429 - val_accuracy: 0.8257
# Epoch 15/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 99439.2355 - accuracy: 0.7028 - val_loss: 99363.8558 - val_accuracy: 0.8991
# Epoch 16/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 99296.1587 - accuracy: 0.6957 - val_loss: 99220.8659 - val_accuracy: 0.8899
# Epoch 17/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 99153.2200 - accuracy: 0.7527 - val_loss: 99078.0565 - val_accuracy: 0.8807
# Epoch 18/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 99010.5996 - accuracy: 0.7082 - val_loss: 98935.5897 - val_accuracy: 0.8073
# Epoch 19/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 98868.1356 - accuracy: 0.7064 - val_loss: 98793.1952 - val_accuracy: 0.8716
# Epoch 20/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 98725.8432 - accuracy: 0.7420 - val_loss: 98650.9915 - val_accuracy: 0.8899
# Epoch 21/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 98583.7592 - accuracy: 0.7544 - val_loss: 98509.0475 - val_accuracy: 0.8899
# Epoch 22/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 98441.8989 - accuracy: 0.7527 - val_loss: 98367.1631 - val_accuracy: 0.8899
# Epoch 23/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 98300.2914 - accuracy: 0.7367 - val_loss: 98225.6798 - val_accuracy: 0.8716
# Epoch 24/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 98158.7949 - accuracy: 0.7669 - val_loss: 98084.3682 - val_accuracy: 0.8716
# Epoch 25/25
# 562/562 [==============================] - 2s 3ms/sample - loss: 98017.5481 - accuracy: 0.7669 - val_loss: 97943.1636 - val_accuracy: 0.8716

# %%
print(classification_report(y_test, y_pred15))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91        71
#            1       0.93      0.68      0.79        38
#
#     accuracy                           0.87       109
#    macro avg       0.89      0.83      0.85       109
# weighted avg       0.88      0.87      0.87       109

# %%
print(confusion_matrix(y_test, y_pred15))
# Out:
# [[69  2]
#  [12 26]]

# %%
plt.plot(history15.history['accuracy'])
plt.plot(history15.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.ylim(0, 1)
plt.xlim(0, 25)
plt.show()

# %%
plt.plot(history15.history['loss'])
plt.plot(history15.history['val_loss'])

# %%
model15.model.save('models/hidden15/')
# Out:
# INFO:tensorflow:Assets written to: models/hidden15/assets
