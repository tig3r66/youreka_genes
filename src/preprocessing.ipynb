# %%
import pandas as pd

# %%
path = 'data/GDSC2_fitted_dose_response_25Feb20.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#   CELL_LINE_NAME       DRUG_NAME   LN_IC50
# 0        HCC1954  5-Fluorouracil  5.530934
# 1        HCC1143  5-Fluorouracil  5.747062
# 2        HCC1187  5-Fluorouracil  6.699858
# 3        HCC1395  5-Fluorouracil  5.841372
# 4        HCC1599  5-Fluorouracil  5.503561

# %%
cleaned_table = pd.pivot_table(df, columns="DRUG_NAME", index="CELL_LINE_NAME", values="LN_IC50")

# %%
clean_df = pd.DataFrame(cleaned_table)
clean_df.head()
# Out:
# DRUG_NAME       5-Fluorouracil    ABT737  AGI-5198  AGI-6780   AMG-319  \
# CELL_LINE_NAME
# 22RV1                 2.478859  3.748055  5.893052  3.901068  6.069160
# 23132-87              2.168003  3.051137  5.095888  5.168499  4.618705
# 42-MG-BA              3.362543  3.022940  4.680624  4.800641  5.247738
# 5637                  3.313258  2.631881  4.544496  4.682486  4.969635
# 639-V                 4.410077  4.331129  3.874526  3.606083  4.519618
#
# DRUG_NAME        AT13148    AZ6102     AZ960   AZD1208   AZD1332  ...  \
# CELL_LINE_NAME                                                    ...
# 22RV1           2.378729  2.771439  3.842732  5.003845  3.422703  ...
# 23132-87        1.398445  2.029025  1.526864  4.671017  1.930872  ...
# 42-MG-BA        3.004648  2.475681  1.071731  5.150479  2.004515  ...
# 5637            5.427145  2.328566  2.147739  5.660901  2.716121  ...
# 639-V           5.290583  2.594762  1.960404  5.307510  1.709686  ...
#
# ...

# %%
clean_df.to_csv('cleaned.csv')
